# %% [markdown]
# ### Museum Analysis for the Whitney Museum

# %% [markdown]
# Source: https://github.com/whitneymuseum/open-access

# %% [markdown]
# ### Before looking at the artworks csv, let's see how many total artists are female (artists.csv)

# %%
from plotnine import *
import pandas as pd

# %%
df = pd.read_csv("whitney-artists.csv", low_memory=False, encoding = 'utf-8')
df.head(2)
# Out:
#      id     display_name  birth_date  death_date
# 0  5208  Berenice Abbott        1898        1991
# 1  5271   Matthew Abbott        1965           0

# %%
len(pd.unique(df['display_name']))
# Out:
# 3721

# %% [markdown]
# ### We're interested in looking at the contemporary gender gap in the artworld, so let's focus on artists who are alive

# %%
df = df[df.death_date == 0]

# %%
len(pd.unique(df['display_name']))
# Out:
# 2035

# %% [markdown]
# ### Since we don't have a column for gender, we're going to use the Artsy API to match gender with the artist name

# %%
#clean up arnet artist names to match with names from the artsy API 
df['artist'] = df['display_name'].str.lower()
df['artist'] = df['artist'].str.replace(" ", "-")
df['artist'] = df['artist'].str.replace("after-", "")
df['artist'] = df['artist'].str.replace(".", "")
df['artist'] = df['artist'].str.replace("é", "e")
df['artist'] = df['artist'].str.replace("è", "e")
df['artist'] = df['artist'].str.replace("è", "e")
df['artist'] = df['artist'].str.replace("&", "and")
df['artist'] = df['artist'].str.replace("í", "i")
df['artist'] = df['artist'].str.replace("á", "a")
df['artist'] = df['artist'].str.replace("attributed-to-", "")
df['artist'] = df['artist'].str.replace("'", "")
df['artist'] = df['artist'].str.replace(",", "")
df['artist'] = df['artist'].str.replace("’", "")
# Out:
# /var/folders/7j/5h5yf6k54nz1ys4trym9bls40000gn/T/ipykernel_67715/2120034449.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.

# %%
import requests
import json

client_id = '0462654e9118c822403d'
client_secret = '5f6c4328fb1499d26260c986f6d2ac12'

# initiate the request to get the token 
r = requests.post("https://api.artsy.net/api/tokens/xapp_token",
                  data={
                      "client_id": client_id,
                      "client_secret": client_secret
                  })

# parse the server response 
j = json.loads(r.text)
j
# extract the token
# Out:
# {'type': 'xapp_token',
#  'token': 'eyJhbGciOiJIUzI1NiJ9.eyJyb2xlcyI6IiIsInN1YmplY3RfYXBwbGljYXRpb24iOiI2MjczZWJjZTg2YTM5NjAwMGM1MjdmYjYiLCJleHAiOjE2NTMzMTg2MjAsImlhdCI6MTY1MjcxMzgyMCwiYXVkIjoiNjI3M2ViY2U4NmEzOTYwMDBjNTI3ZmI2IiwiaXNzIjoiR3Jhdml0eSIsImp0aSI6IjYyODI2OTVjZjAzOWQ5MDAwZTA0ZDVhYyJ9.VLIWDU3V1FB0THy0PwBqhsG1rwpUJVpicG_sNY_pDks',
#  'expires_at': '2022-05-23T15:10:20+00:00',
#  '_links': {}}

# %%
# create a header containing our token 
headers = {"X-Xapp-Token" : 'eyJhbGciOiJIUzI1NiJ9.eyJyb2xlcyI6IiIsInN1YmplY3RfYXBwbGljYXRpb24iOiI2MjczZWJjZTg2YTM5NjAwMGM1MjdmYjYiLCJleHAiOjE2NTMzMTg2MjAsImlhdCI6MTY1MjcxMzgyMCwiYXVkIjoiNjI3M2ViY2U4NmEzOTYwMDBjNTI3ZmI2IiwiaXNzIjoiR3Jhdml0eSIsImp0aSI6IjYyODI2OTVjZjAzOWQ5MDAwZTA0ZDVhYyJ9.VLIWDU3V1FB0THy0PwBqhsG1rwpUJVpicG_sNY_pDks'}
# initiate a request with the header 



r = requests.get("https://api.artsy.net/api/artists/a.g.-rizzoli'", headers=headers)

# parse the server response 
j = json.loads(r.text)
j
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /var/folders/7j/5h5yf6k54nz1ys4trym9bls40000gn/T/ipykernel_67715/776407105.py in <module>
#       8
#       9 # parse the server response
# ---> 10 j = json.loads(r.text)
#      11 j
#
# ~/.pyenv/versions/3.10.0/lib/python3.10/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# ~/.pyenv/versions/3.10.0/lib/python3.10/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
# ...

# %%
import time 

case_list = []

errors = []
for name in df['artist'].unique():
        print(name)
        try:
            url = "https://api.artsy.net/api/artists/" + name  #name is the name of the artist we're looking for 
            url = f"{url}"  #puts quotes aruond url 
            print(url)
            r = requests.get(url, headers=headers)
            j = json.loads(r.text)
            
            
            artist = j['slug']
       

            case = {'artist': j['slug'], 'gender': j['gender'], 'nationality': j['nationality'], 'birthday': j['birthday'], 'hometown': j['hometown']}
            case_list.append(case)
            time.sleep(0.2)
        except:
            print("error", name)
            errors.append(name)
# Out:
# matthew-abbott
# https://api.artsy.net/api/artists/matthew-abbott
# michele-abeles
# https://api.artsy.net/api/artists/michele-abeles
# sigmund-abeles
# https://api.artsy.net/api/artists/sigmund-abeles
# satoru-abe
# https://api.artsy.net/api/artists/satoru-abe
# marina-abramovic
# https://api.artsy.net/api/artists/marina-abramovic
# error marina-abramovic
# juan-abreu
# https://api.artsy.net/api/artists/juan-abreu
# error juan-abreu
# keith-achepol
# https://api.artsy.net/api/artists/keith-achepol
# error keith-achepol
# alice-adams
# https://api.artsy.net/api/artists/alice-adams
# dennis-adams
# https://api.artsy.net/api/artists/dennis-adams
# pat-adams
# https://api.artsy.net/api/artists/pat-adams
# robert-adams
# https://api.artsy.net/api/artists/robert-adams
# shelby-lee-adams
# https://api.artsy.net/api/artists/shelby-lee-adams
# lee-adler
# https://api.artsy.net/api/artists/lee-adler
# error lee-adler
# nicholas-africano
# https://api.artsy.net/api/artists/nicholas-africano
# ...

# %% [markdown]
# ### So we were able to match the gender for 1514 artists with artworks in the Whitney (out of 2035)

# %%
new = pd.DataFrame.from_dict(case_list)
new
# Out:
#                artist  gender nationality birthday  \
# 0      matthew-abbott    male     British     1965
# 1      michele-abeles  female    American     1977
# 2      sigmund-abeles    None    American     1934
# 3          satoru-abe    male    American     1926
# 4         alice-adams    None    American     1930
# ...               ...     ...         ...      ...
# 1509     eddie-arroyo    male    American     1976
# 1510   mequitta-ahuja  female    American     1976
# 1511  juanita-mcneely  female    American     1936
# 1512    lauren-halsey  female                 1987
# 1513       chase-hall    male                 1993
#
#                          hometown
# 0          London, United Kingdom
# 1
# 2
# 3     Honolulu, HI, United States
# 4
# ...                           ...
# 1509
# 1510
# 1511           St. Louis, MO, USA
# 1512
# 1513          Saint Paul, MN, USA
#
# [1514 rows x 5 columns]

# %% [markdown]
# ### The analysis shows that 31% of artists in the Whitney Museum are female

# %%
new.gender.value_counts()
# Out:
# male         840
# female       481
#               36
# n/a            7
# nonbinary      5
# Name: gender, dtype: int64
